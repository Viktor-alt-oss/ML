# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Авторские права принадлежат Pierian Data Inc.</em></center>
# <center><em>Для дополнительной информации посетите наш сайт <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Датафреймы - DataFrames
#
# На протяжении всего курсы мы будем очень много работать с объектами DataFrame. Они являются естественным продолжением Pandas Series. Определение DataFrame следующее:
#
# **Pandas DataFrame состоит из нескольких объектов Pandas Series с общими значениями индекса.**
#
#
# По сути, если Series - это **одномерный** проиндексированный массив, то DataFrame - **многомерный** проиндексированный массив, в котором каждый столбец является массивом Series.
#
# Давайте рассмотрим на примерах.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Создаём DataFrame на основе объектов Python

# %%
# help(pd.DataFrame)

# %%
# Убедитесь, что команда seed находится в той же ячейке, что и команда random
# https://stackoverflow.com/questions/21494489/what-does-numpy-random-seed0-do
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['CA','NY','AZ','TX']

# %%
mycolumns = ['Jan','Feb','Mar']

# %%
df = pd.DataFrame(data=mydata)
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data=mydata,index=myindex)
df
# Out:
#      0   1   2
# CA  95  11  81
# NY  70  63  87
# AZ  75   9  77
# TX  40   4  63

# %%
df = pd.DataFrame(data=mydata,index=myindex,columns=mycolumns)
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int32
#  1   Feb     4 non-null      int32
#  2   Mar     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %% [markdown]
# # Загружаем файл .csv file в DataFrame
#
# ----
#
# ## Замечание: Позже в этом курсе мы рассмотрим много различных типов файлов - .html, .csv, .xlsx и другие! Но сейчас мы ограничимся только файлом .csv.
#
# ----

# %% [markdown]
# ## CSV
# Файлы CSV (Comma Separated Values) содержат отдельные значения данных, отделённые друг от друга с помощью знаков-разделителей.<br>
# Если Вы НЕ используете виртуальную среду, предлагаемую в этом курсе, то Вам может потребоваться установка библиотек <tt>xlrd</tt> и <tt>openpyxl</tt>.<br>
# В Вашем терминале или командной строке выполните следующие команды:
#
#     conda install xlrd
#     conda install openpyxl
#
# (если Вы не используете Anaconda Distribution, то вместо conda install напишите pip install)
#
# После этого перезапустите Jupyter Notebook.
#
# ### Путь к файлу
#
# Когда нужно обратиться к файлу в pandas, то есть два варианта:
#
# 1. Если Ваш файл .csv находится **в той же самой** папке, что и файл .py или блокнот .ipynb, то можно просто указать название этого файла .csv. Например:
#
#         df = pd.read_csv('some_file.csv')
#
# 2. Либо второй вариант - если файл .csv находится в другой папке, то можно указать полный путь к файлу. Обратите внимание, что путь должен быть на 100% правильным, без единой опечатки. Например:
#
#         df = pd.read_csv("C:\\Users\\myself\\files\\some_file.csv")

# %% [markdown]
# #### Отобразить текущую папку можно с помощью команды pwd

# %%
pwd
# Out:
# 'C:\\work\\jupiter_ML\\ML_course\\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V9\\03-Pandas'

# %% [markdown]
# #### Вывести список файлов в текущей папке - команда ls

# %%
ls
# Out:
#  ’®¬ ў гбва®©бвўҐ C Ё¬ҐҐв ¬ҐвЄг Windows-SSD
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : 4E76-F254
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ C:\work\jupiter_ML\ML_course\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V9\03-Pandas
#
# 10.09.2024  23:46    <DIR>          .
# 08.09.2024  12:01    <DIR>          ..
# 10.09.2024  22:45    <DIR>          .ipynb_checkpoints
# 08.09.2024  12:01    <DIR>          __pycache__
# 10.09.2024  21:52         1я301я173 00-Series.ipynb
# 10.09.2024  23:46           332я354 01-DataFrames.ipynb
# 08.09.2024  12:01           195я623 02-Conditional-Filtering.ipynb
# 08.09.2024  12:01           196я925 03-Useful-Methods.ipynb
# 08.09.2024  12:01            65я702 04-Missing-Data.ipynb
# 08.09.2024  12:01           247я978 05-Groupby-Operations-and-MultiIndex.ipynb
# 08.09.2024  12:01            66я225 06-Combining-DataFrames.ipynb
# 08.09.2024  12:01            34я195 07-Text-Methods.ipynb
# 08.09.2024  12:01            96я529 08-Time-Methods.ipynb
# ...

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ----
# Подробности об этом наборе данных (если Вам интересно)
#
# * Описание
#     * Один официант записывал информацию о чаевых, которые он получал с течении нескольких месяцев, работая в ресторане.
#
# * Формат
#     * 244 строк и 7 переменных
#
# * Для каждого факта получения чаевых этот официант записал следующую информацию:
#     * Сумма чаевых в долларах (tip)
#     * Сумма счёта в долларах (total_bill)
#     * Пол человека, оплатившего счёт (sex)
#     * Были ли в компании курящие (smoker)
#     * День недели (day)
#     * Время дня (time)
#     * Количество человек в компании (size)
#
# Всего он сделал 244 записи. Эти данные были использованы для исследований по применению статистики для бизнес-задач (Bryant & Smith 1995).
#
# * Литература
#     * Bryant, P. G. and Smith, M (1995) Practical Data Analysis: Case Studies in Business Statistics. Homewood, IL: Richard D. Irwin Publishing:
#
# * Замечание: Мы добавили несколько колонок с вымышленными данными - имя (Name), номер банковской карты (CC Number) и идентификатор платежа (Payment ID).
#
# ----

# %% [markdown]
# # DataFrames

# %% [markdown]
# ## Как получить базовую информацию об объекте DataFrame

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
len(df)
# Out:
# 244

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# ## Индексирование
#
# Давайте узнаем, как можно извлекать данные из DataFrame.

# %% [markdown]
# ### КОЛОНКИ

# %% [markdown]
# Начнём с того, как получить данные на основе колонок

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# #### Берём одну колонку

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Берём несколько колонок

# %%
# Обратите внимание, что здесь мы передаём названия колонок в виде списка (list). 
# Поэтому здесь два набора квадратных скобок.
df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %% [markdown]
# #### Создание новых колонок

# %%
df['tip_percentage'] = 100* df['tip'] / df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
df['price_per_person'] = df['total_bill'] / df['size']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3          7.003333
# 3       23.68  3.31    Male     No  Sun  Dinner     2         11.840000
# 4       24.59  3.61  Female     No  Sun  Dinner     4          6.147500
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
help(np.round)
# Out:
# Help on _ArrayFunctionDispatcher in module numpy:
#
# round(a, decimals=0, out=None)
#     Evenly round to the given number of decimals.
#
#     Parameters
#     ----------
#     a : array_like
#         Input data.
#     decimals : int, optional
#         Number of decimal places to round to (default: 0).  If
#         decimals is negative, it specifies the number of positions to
#         the left of the decimal point.
#     out : ndarray, optional
#         Alternative output array in which to place the result. It must have
#         the same shape as the expected output, but the type of the output
#         values will be cast if necessary. See :ref:`ufuncs-output-type` for more
#         details.
#
#     Returns
#     -------
#     rounded_array : ndarray
#         An array of the same type as `a`, containing the rounded values.
#         Unless `out` was specified, a new array is created.  A reference to
#         the result is returned.
#
# ...

# %% [markdown]
# #### Изменение данных в существующих колонках

# %%
# Поскольку pandas основан на numpy, мы можем очень удобно применять универсальные функции numpy!
df['price_per_person'] = np.round(df['price_per_person'],2)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %% [markdown]
# #### Удаление колонок

# %%
# df.drop('tip_percentage',axis=1)

# %%
df = df.drop("tip_percentage",axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # Основы работы с индексами
#
# Прежде чем перейти в аналогичным действиям не с колонками, а со строками, давайте сначала разберёмся, как работает индексация в pandas DataFrame.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
# Обратите внимание - здесь мы не меняем df, а только отображаем результат метода set_index
df.set_index('Payment ID')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# А теперь поменяем сам df - сохраним в нём результат работы метода set_index
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %% [markdown]
# ### СТРОКИ
#
# Теперь давайте применим те же идеи для строк.

# %%
df.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %%
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %% [markdown]
# #### Берём одну строку

# %%
# На основе номера строки - числа Integer
df.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
# На основе названия (на основе значения колонки-индекса)
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %% [markdown]
# #### Берём несколько строк

# %%
df.iloc[0:4]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df.loc[['Sun2959','Sun5260']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %% [markdown]
# #### Удаляем строки
#
# Поскольку обычно наборы данных содержат очень много строк, мы почти никогда не удаляем строки, указывая номера строк. Вместо этого мы обычно удаляем строки на основе каких-то условий, например если какие-то данные отсутствуют в колонках. В следующей лекции мы разберём это более подробно.

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df.drop('Sun2959',axis=0).head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# Sun2251                 6.15      Tonya Carter  4832732618637221
# Sun9679                 6.32        Erik Smith   213140353657882

# %%
# Приведёт к ошибке, если у Вас есть именованный индекс!
# df.drop(0,axis=0).head()

# %% [markdown]
# #### Вставка новой строки
#
# Такая вставка одной строки встречается очень редко. Чаще используется pd.concat() для вставки сразу нескольких строк.
# Ещё можно применить метод .append() для списка объектов pd.Series(), но это тоже скорее редкие случаи.

# %%
one_row = df.iloc[0]

# %%
one_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
type(one_row)
# Out:
# pandas.core.series.Series

# %%
df.tail()
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person       Payer Name         CC Number
# Payment ID
# Sat2657                 9.68    Michael Avila  5296068606052842
# Sat1766                13.59   Monica Sanders  3506806155565404
# Sat3880                11.34       Keith Wong  6011891618747196
# Sat17                   8.91     Dennis Dixon     4375220550950
# Thur672                 9.39  Michelle Hardin  3511451626698139

# %%
pd.concat([df, pd.DataFrame([one_row])], axis=0).tail()

# Вместо df.append в будущих версиях Pandas следует использовать pd.concat().
# Вот пример кода - здесь one_row это объект Series:
# pd.concat([df,pd.DataFrame([one_row])],axis=0)
# Out:
#          total_bill   tip     sex smoker   day    time  size  \
# Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
#
#          price_per_person          Payer Name         CC Number
# Sat1766             13.59      Monica Sanders  3506806155565404
# Sat3880             11.34          Keith Wong  6011891618747196
# Sat17                8.91        Dennis Dixon     4375220550950
# Thur672              9.39     Michelle Hardin  3511451626698139
# Sun2959              8.49  Christy Cunningham  3560325168603410

# %%
# Вместо df.append в будущих версиях Pandas следует использовать pd.concat().
# Вот пример кода - здесь one_row это объект Series:
# pd.concat([df,pd.DataFrame([one_row])],axis=0)

# %%
print('Отличная Работа')

# %%
import numpy as np

# %%
import pandas as pd

# %%
np.random.seed(101)
mydata = np.random.randint(0, 101, (4, 3))
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['CA', 'NY', 'AZ', 'TX']

# %%
mycolumns = ['Jan', 'Feb', 'Mar']

# %%
df_0 = pd.DataFrame(mydata)

# %%
df_0
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(mydata, myindex, mycolumns)

# %%
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int32
#  1   Feb     4 non-null      int32
#  2   Mar     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
pwd # где находится файл
# Out:
# 'C:\\work\\jupiter_ML\\ML_course\\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V9\\03-Pandas'

# %%
ls
# Out:
#  ’®¬ ў гбва®©бвўҐ C Ё¬ҐҐв ¬ҐвЄг Windows-SSD
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : 4E76-F254
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ C:\work\jupiter_ML\ML_course\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V9\03-Pandas
#
# 10.09.2024  23:46    <DIR>          .
# 08.09.2024  12:01    <DIR>          ..
# 10.09.2024  22:45    <DIR>          .ipynb_checkpoints
# 08.09.2024  12:01    <DIR>          __pycache__
# 10.09.2024  21:52         1я301я173 00-Series.ipynb
# 10.09.2024  23:46           332я354 01-DataFrames.ipynb
# 08.09.2024  12:01           195я623 02-Conditional-Filtering.ipynb
# 08.09.2024  12:01           196я925 03-Useful-Methods.ipynb
# 08.09.2024  12:01            65я702 04-Missing-Data.ipynb
# 08.09.2024  12:01           247я978 05-Groupby-Operations-and-MultiIndex.ipynb
# 08.09.2024  12:01            66я225 06-Combining-DataFrames.ipynb
# 08.09.2024  12:01            34я195 07-Text-Methods.ipynb
# 08.09.2024  12:01            96я529 08-Time-Methods.ipynb
# ...

# %%
df_tips = pd.read_csv('tips.csv')

# %%
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df_tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df_tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df_tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()
# Out:
#              Jan        Feb        Mar
# count   4.000000   4.000000   4.000000
# mean   70.000000  21.750000  77.000000
# std    22.730303  27.657127  10.198039
# min    40.000000   4.000000  63.000000
# 25%    62.500000   7.750000  73.500000
# 50%    72.500000  10.000000  79.000000
# 75%    80.000000  24.000000  82.500000
# max    95.000000  63.000000  87.000000

# %%
df_tips.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df_tips.T
# Out:
#                                  0                 1                 2    \
# total_bill                     16.99             10.34             21.01
# tip                             1.01              1.66               3.5
# sex                           Female              Male              Male
# smoker                            No                No                No
# day                              Sun               Sun               Sun
# time                          Dinner            Dinner            Dinner
# size                               2                 3                 3
# price_per_person                8.49              3.45               7.0
# Payer Name        Christy Cunningham    Douglas Tucker    Travis Walters
# CC Number           3560325168603410  4478071379779230  6011812112971322
# Payment ID                   Sun2959           Sun4608           Sun4458
#
#                                3                 4                5    \
# ...

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df_tips.transpose()
# Out:
#                                  0                 1                 2    \
# total_bill                     16.99             10.34             21.01
# tip                             1.01              1.66               3.5
# sex                           Female              Male              Male
# smoker                            No                No                No
# day                              Sun               Sun               Sun
# time                          Dinner            Dinner            Dinner
# size                               2                 3                 3
# price_per_person                8.49              3.45               7.0
# Payer Name        Christy Cunningham    Douglas Tucker    Travis Walters
# CC Number           3560325168603410  4478071379779230  6011812112971322
# Payment ID                   Sun2959           Sun4608           Sun4458
#
#                                3                 4                5    \
# ...

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df_tips['total_bill ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_bill '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[511], line 1
# ----> 1 df_tips['total_bill ']
#
# ...

# %%
type(df_tips['total_bill'])

# %%
mycols = ['total_bill', 'tip']

# %%
df_tips[mycols]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df_tips[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df_tips['tip_percentage'] = 100 * df_tips['tip'] / df_tips['total_bill']

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
df_tips['price_per_person'] = df_tips['price_per_person'] + 1

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              9.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              4.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              8.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             12.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              7.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3             10.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             14.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             12.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              9.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2             10.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              9.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              4.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              8.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             12.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              7.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3             10.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             14.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             12.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              9.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2             10.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
np.round(df_tips, 2)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              9.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              4.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              8.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             12.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              7.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3             10.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             14.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             12.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              9.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2             10.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              9.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              4.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              8.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             12.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              7.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3             10.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             14.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             12.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              9.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2             10.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
df_tips = df_tips.drop('tip_percentage', axis=1)

# %%
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              9.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              4.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              8.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             12.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              7.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3             10.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             14.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             12.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              9.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2             10.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df_tips.shape
# Out:
# (244, 11)

# %%
df_tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              9.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              4.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              8.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             12.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              7.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df_tips = df_tips.set_index('Payment ID')

# %%
df_tips
# Out:
#             index  total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608         1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251         4       24.59  3.61  Female     No   Sun  Dinner     4
# ...           ...         ...   ...     ...    ...   ...     ...   ...
# Sat2657       239       29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766       240       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       241       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         242       17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       243       18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# ...

# %%
df_tips = df_tips.reset_index()

# %%
df_tips
# Out:
#     Payment ID  index  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959      0       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608      1       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458      2       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260      3       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251      4       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...    ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657    239       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766    240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880    241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17    242       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672    243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# ...

# %%
df_tips.head()
# Out:
#   Payment ID  index  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959      0       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608      1       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458      2       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260      3       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251      4       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              9.49  Christy Cunningham  3560325168603410
# 1              4.45      Douglas Tucker  4478071379779230
# 2              8.00      Travis Walters  6011812112971322
# 3             12.84    Nathaniel Harris  4676137647685994
# 4              7.15        Tonya Carter  4832732618637221

# %%
df_tips.iloc[0]
# Out:
# Payment ID                     Sun2959
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  9.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: 0, dtype: object

# %%
df_tips = df_tips.set_index('Payment ID')

# %%
df_tips.loc['Sun2959']
# Out:
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  9.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df_tips.iloc[0]
# Out:
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  9.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df_tips.iloc[0:4]
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608         1       10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 9.49  Christy Cunningham  3560325168603410
# Sun4608                 4.45      Douglas Tucker  4478071379779230
# Sun4458                 8.00      Travis Walters  6011812112971322
# Sun5260                12.84    Nathaniel Harris  4676137647685994

# %%
df_tips.loc[['Sun2959', 'Sun5260']]
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 9.49  Christy Cunningham  3560325168603410
# Sun5260                12.84    Nathaniel Harris  4676137647685994

# %%
df_tips = df_tips.drop('Sun2959')

# %%
df_tips
# Out:
#             index  total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608         1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251         4       24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679         5       25.29  4.71    Male     No   Sun  Dinner     4
# ...           ...         ...   ...     ...    ...   ...     ...   ...
# Sat2657       239       29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766       240       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       241       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         242       17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       243       18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# ...

# %%
one_row = df_tips.iloc[0]

# %%
one_row
# Out:
# index                              1
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                4.45
# Payer Name            Douglas Tucker
# CC Number           4478071379779230
# Name: Sun4608, dtype: object

# %%
pd.concat([df_tips, pd.DataFrame([one_row])], axis=0)
# Out:
#          index  total_bill   tip     sex smoker   day    time  size  \
# Sun4608      1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458      2       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260      3       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251      4       24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679      5       25.29  4.71    Male     No   Sun  Dinner     4
# ...        ...         ...   ...     ...    ...   ...     ...   ...
# Sat17      242       17.82  1.75    Male     No   Sat  Dinner     2
# Thur672    243       18.78  3.00  Female     No  Thur  Dinner     2
# Sun4608      1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4608      1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4608      1       10.34  1.66    Male     No   Sun  Dinner     3
#
#          price_per_person        Payer Name         CC Number
# Sun4608              4.45    Douglas Tucker  4478071379779230
# ...

# %%
df_tips
# Out:
#          index  total_bill   tip     sex smoker   day    time  size  \
# Sun4608      1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458      2       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260      3       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251      4       24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679      5       25.29  4.71    Male     No   Sun  Dinner     4
# ...        ...         ...   ...     ...    ...   ...     ...   ...
# Sat3880    241       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17      242       17.82  1.75    Male     No   Sat  Dinner     2
# Thur672    243       18.78  3.00  Female     No  Thur  Dinner     2
# Sun4608      1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4608      1       10.34  1.66    Male     No   Sun  Dinner     3
#
#          price_per_person        Payer Name         CC Number
# Sun4608              4.45    Douglas Tucker  4478071379779230
# ...
