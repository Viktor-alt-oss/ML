# %%
import pandas as pd

# %%
url = r"C:\Users\virgi\OneDrive\Рабочий стол\Единобоства\133.xlsx"

# %%
dataframe = pd.read_excel(url, sheet_name=1)

# %%
dataframe.head(-1)
# Out:
#    Unnamed: 0                                        Хореография  Unnamed: 2  \
# 0         NaN                                Сад №______________         NaN
# 1         NaN  Время  занятий________________________________...         NaN
# 2         NaN  Тренер________________________________________...         NaN
# 3         NaN                                                NaN         NaN
# 4       № п п                                             Ф.И.О.         NaN
# 5           1                                                NaN         NaN
# 6           2                                                NaN         NaN
# 7           3                                                NaN         NaN
# 8           4                                                NaN         NaN
# 9           5                                                NaN         NaN
# 10          6                                                NaN         NaN
# ...
